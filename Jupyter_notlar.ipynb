# %%
import pandas as pd

# %%
nobel_db=pd.read_csv("nobel.csv")
nobel_db.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...      01-Jan          160
# 1  "in special recognition of his poetic composit...      01-Jan          569
# 2  "for his work on serum therapy, especially its...      01-Jan          293
# 3                                                NaN      01-Feb          462
# 4                                                NaN      01-Feb          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
kazanan_kadinlar = nobel_db[nobel_db["sex"] == "Female"]

# %%
kazanan_kadinlar
# Out:
#      year    category                                              prize  \
# 19   1903     Physics                    The Nobel Prize in Physics 1903
# 29   1905       Peace                         The Nobel Peace Prize 1905
# 51   1909  Literature                 The Nobel Prize in Literature 1909
# 62   1911   Chemistry                  The Nobel Prize in Chemistry 1911
# 128  1926  Literature                 The Nobel Prize in Literature 1926
# 141  1928  Literature                 The Nobel Prize in Literature 1928
# 160  1931       Peace                         The Nobel Peace Prize 1931
# 179  1935   Chemistry                  The Nobel Prize in Chemistry 1935
# 198  1938  Literature                 The Nobel Prize in Literature 1938
# 218  1945  Literature                 The Nobel Prize in Literature 1945
# 229  1946       Peace                         The Nobel Peace Prize 1946
# 235  1947    Medicine     The Nobel Prize in Physiology or Medicine 1947
# ...

# %%
ilk_kazanan_kadinlar = kazanan_kadinlar.sort_values("year").drop_duplicates("category")
print(ilk_kazanan_kadinlar[["category", "full_name", "year"]])
# Out:
#        category                                          full_name  year
# 19      Physics                        Marie Curie, née Sklodowska  1903
# 29        Peace  Baroness Bertha Sophie Felicita von Suttner, n...  1905
# 51   Literature                      Selma Ottilia Lovisa Lagerlöf  1909
# 62    Chemistry                        Marie Curie, née Sklodowska  1911
# 235    Medicine                    Gerty Theresa Cori, née Radnitz  1947
# 819   Economics                                      Elinor Ostrom  2009

# %%
kazanan_erkekler = nobel_db[nobel_db["sex"] == "Male"] 
ilk_kazanan_erkekler = kazanan_erkekler.sort_values("year").drop_duplicates("category")
print(ilk_kazanan_erkekler[["category", "full_name", "year"]])
# Out:
#        category                     full_name  year
# 0     Chemistry  Jacobus Henricus van 't Hoff  1901
# 1    Literature               Sully Prudhomme  1901
# 2      Medicine        Emil Adolf von Behring  1901
# 3         Peace             Jean Henry Dunant  1901
# 5       Physics        Wilhelm Conrad Röntgen  1901
# 393   Economics                 Ragnar Frisch  1969

# %%
len(nobel_db["category"].unique())
# Out:
# 6

# %%
nobel_db.category.unique()
# Out:
# array(['Chemistry', 'Literature', 'Medicine', 'Peace', 'Physics',
#        'Economics'], dtype=object)

# %%
ulke_say = nobel_db["organization_country"].value_counts()

# %%
top_10_countries = ulke_say.head(10)

# %%
print(top_10_countries)
# Out:
# organization_country
# United States of America               341
# United Kingdom                          89
# Germany                                 43
# France                                  36
# Federal Republic of Germany             23
# Switzerland                             21
# Sweden                                  17
# Japan                                   16
# Netherlands                             11
# Union of Soviet Socialist Republics      9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top_10_countries.plot()
# Out:
# <Axes: xlabel='organization_country'>

# %%
top_1_countries = ulke_say.head(1)
print(top_1_countries)
# Out:
# organization_country
# United States of America    341
# Name: count, dtype: int64

# %%
# Her yılın toplam ödül sayısını ve en çok ödül kazanan ülkeyi bul
yearly_awards = nobel_db.groupby(['year', 'organization_country']).size().reset_index(name='count')
most_awarded_country = yearly_awards.loc[yearly_awards.groupby('year')['count'].idxmax()]

# En çok ödül kazanan ülkenin ilk hakim olduğu yılı bul
most_awarded_country['first_year_as_dominant'] = most_awarded_country.groupby('organization_country')['year'].transform('min')

# Grafik çizimi
plt.figure(figsize=(10, 6))
plt.plot(most_awarded_country['year'], most_awarded_country['count'], marker='o', linestyle='-')
plt.title('En Çok Ödül Kazanan Ülkenin Yıllara Göre Ödül Sayısı')
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.grid(True)
plt.show()

# %%
# organization_country sütununa göre gruplayıp toplam ödül sayısını hesapla
awards_by_country = nobel_db['organization_country'].value_counts()

# En çok ödül kazanan ülkeyi bul
most_awarded_country = awards_by_country.idxmax()
most_awarded_count = awards_by_country.max()

print(f"En çok ödül kazanan ülke: {most_awarded_country} ({most_awarded_count} ödül)")

# Görselleştirme
plt.figure(figsize=(10, 6))
awards_by_country.head(10).plot(kind='bar')
plt.title('En Çok Ödül Kazanan Ülkeler')
plt.xlabel('Ülke')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.show()
# Out:
# En çok ödül kazanan ülke: United States of America (341 ödül)

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin kategorilerine göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_category = most_awarded_country_df['category'].value_counts()

# Görselleştirme
plt.figure(figsize=(10, 6))
awards_by_category.plot(kind='bar')
plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Kategorilere Göre Dağılımı")
plt.xlabel('Kategori')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country =nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(12, 12))
awards_by_year_and_category.plot(kind='bar', stacked=True)
plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Yıllara ve Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori')
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla
awards_by_year_and_category.plot(kind='line', marker='o', linestyle='-', stacked=True)
plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Yıllara ve Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori')
plt.grid(True)
plt.ylim(0, awards_by_year_and_category.max().max() * 1.1)  # Y ekseni aralığını belirle
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# Her kategori için ayrı bir çizgi grafiği çiz
for category in awards_by_year_and_category.columns:
    plt.plot(awards_by_year_and_category.index, awards_by_year_and_category[category], marker='o', label=category)

plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Yıllara ve Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Her yılın en çok kazanılan kategorisini bul
most_awarded_category_per_year = awards_by_year_and_category.idxmax(axis=1)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# En çok kazanılan kategorinin çizgi grafiğini çiz
plt.plot(most_awarded_category_per_year.index, most_awarded_category_per_year.values, marker='o', linestyle='-')

plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin En Çok Kazanılan Kategoriye Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('En Çok Kazanılan Kategori')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# Her kategori için ayrı bir çizgi grafiği çiz
for category in awards_by_year_and_category.columns:
    plt.plot(awards_by_year_and_category.index, awards_by_year_and_category[category], marker='o', linestyle='-', label=category)

plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# Her kategori için ayrı bir alan grafiği çiz
for category in awards_by_year_and_category.columns:
    plt.fill_between(awards_by_year_and_category.index, awards_by_year_and_category[category], label=category, alpha=0.7)

plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori', bbox_to_anchor=(1.01, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# Alanları üst üste eklemek için bir döngü kullan
cumulative_values = pd.Series(index=awards_by_year_and_category.index, data=0)
for category in awards_by_year_and_category.columns:
    plt.fill_between(awards_by_year_and_category.index, cumulative_values, cumulative_values + awards_by_year_and_category[category], label=category, alpha=0.7)
    cumulative_values += awards_by_year_and_category[category]

plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin Kategorilere Göre Dağılımı")
plt.xlabel('Yıl')
plt.ylabel('Toplam Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Kategori', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# En çok ödül kazanan ülkenin adını al
most_awarded_country = nobel_db['organization_country'].value_counts().idxmax()

# En çok ödül kazanan ülkenin aldığı ödüllerin yıllara ve kategorilere göre gruplayıp say
most_awarded_country_df = nobel_db[nobel_db['organization_country'] == most_awarded_country]
awards_by_year_and_category = most_awarded_country_df.groupby(['year', 'category']).size().unstack(fill_value=0)

# Her bir kategori için ayrı grafik çiz
for category in awards_by_year_and_category.columns:
    plt.figure(figsize=(10, 6))
    plt.plot(awards_by_year_and_category.index, awards_by_year_and_category[category], marker='o', linestyle='-')
    plt.title(f"{most_awarded_country} Tarafından Kazanılan Nobel Ödüllerinin '{category}' Kategorisinin Yıllara Göre Dağılımı")
    plt.xlabel('Yıl')
    plt.ylabel('Ödül Sayısı')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Ülkelerin toplam ödül sayılarını hesapla
awards_by_country = nobel_db['organization_country'].value_counts()

# En çok ödül kazanan ilk 10 ülkeyi belirle
top_5_countries = awards_by_country.head(5).index

# Seçilen ülkelerin yıllara göre aldığı ödül sayılarını hesapla
awards_by_year_and_top_countries = nobel_db[nobel_db['organization_country'].isin(top_5_countries)].groupby(['year', 'organization_country']).size().unstack(fill_value=0)

# Görselleştirme
plt.figure(figsize=(20, 10))  # Boyutu 20x10 olarak ayarla

# En çok ödül kazanan ilk 10 ülkenin yıllara göre ödül sayılarını çiz
for country in awards_by_year_and_top_countries.columns:
    plt.plot(awards_by_year_and_top_countries.index, awards_by_year_and_top_countries[country], marker='o', linestyle='-', label=country)

plt.title('En Çok Ödül Kazanan 5 Ülkenin Yıllara Göre Aldığı Nobel Ödüllerinin Dağılımı')
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')
plt.xticks(rotation=45)
plt.legend(title='Ülke', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# 'birth_date' sütunundaki boş değerleri içeren satırları filtreleyin
missing_birth_date = nobel_db[nobel_db['birth_date'].isnull()]

# Boş 'birth_date' değerlerine sahip satır sayısını yazdırın
print("Boş 'birth_date' değerlerine sahip satır sayısı:", len(missing_birth_date))
# Out:
# Boş 'birth_date' değerlerine sahip satır sayısı: 28

# %%
# Cinsiyet dağılımını al
sex_distribution = nobel_db['sex'].value_counts()

# Görselleştirme
plt.figure(figsize=(6, 6))
sex_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'pink'])
plt.title('Nobel Ödülü Kazananların Cinsiyet Dağılımı')
plt.ylabel('')
plt.show()

# %%
# Ödül kategorilerini al
categories = nobel_db['category'].unique()

# Her bir kategori için ayrı görselleştirme yap
for category in categories:
    # Belirli kategoriye ait veriyi filtrele
    category_data = nobel_db[nobel_db['category'] == category]
    
    # Cinsiyet dağılımını al
    sex_distribution = category_data['sex'].value_counts()
    
    # Görselleştirme
    plt.figure(figsize=(6, 6))
    sex_distribution.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'pink'])
    plt.title(f'{category} Kategorisinde Nobel Ödülü Kazananların Cinsiyet Dağılımı')
    plt.ylabel('')
    plt.show()

# %%
nobel_db
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
# Tüm tarihleri aynı formata dönüştür
nobel_db['birth_date'] = pd.to_datetime(nobel_db['birth_date'], errors='coerce')
# Yeni sütunu doğrudan hesaplayarak ekle
nobel_db['age_at_award'] = nobel_db['year'] - pd.to_datetime(nobel_db['birth_date']).dt.year

# DataFrame'i yazdır
print(nobel_db)
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
# Tüm tarihleri aynı formata dönüştür
nobel_db['birth_date'] = pd.to_datetime(nobel_db['birth_date'], errors='coerce')

# Birth_date sütununda eksik veya hatalı değerlerin olduğunu kontrol et
missing_dates = nobel_db[nobel_db['birth_date'].isnull()]
print("Eksik veya hatalı tarihlerin sayısı:", len(missing_dates))

# Birth_date sütununda eksik veya hatalı tarihlerin olduğu satırları veriden kaldır
nobel_db = nobel_db.dropna(subset=['birth_date'])

# Yaşları hesaplamak için birth_date sütunundaki tarihlerden doğum yıllarını alarak yeni bir sütun ekle
nobel_db['age_at_award'] = nobel_db['year'] - nobel_db['birth_date'].dt.year

# DataFrame'i yazdır
print(nobel_db)
# Out:
# Eksik veya hatalı tarihlerin sayısı: 624
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 473  1977   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 475  1977  Literature                 The Nobel Prize in Literature 1977
# 482  1977     Physics                    The Nobel Prize in Physics 1977
# 491  1978     Physics                    The Nobel Prize in Physics 1978
# 495  1979   Chemistry                  The Nobel Prize in Chemistry 1979
#
# ...

# %%
# Tüm tarihleri aynı formata dönüştür
nobel_db['birth_date'] = pd.to_datetime(nobel_db['birth_date'], errors='coerce')

# Birth_date sütununda eksik veya hatalı değerlerin olduğunu kontrol et
missing_dates = nobel_db[nobel_db['birth_date'].isnull()]
print("Eksik veya hatalı tarihlerin sayısı:", len(missing_dates))

# Birth_date sütununda eksik veya hatalı tarihlerin olduğu satırları veriden kaldır
nobel_db = nobel_db.dropna(subset=['birth_date'])

# Yaşları hesaplamak için birth_date sütunundaki tarihlerden doğum yıllarını alarak yeni bir sütun ekle
nobel_db['year'] = pd.to_datetime(nobel_db['year']).dt.year
nobel_db['age_at_award'] = nobel_db['year'] - nobel_db['birth_date'].dt.year

# DataFrame'i yazdır
print(nobel_db)
# Out:
# Eksik veya hatalı tarihlerin sayısı: 0
#      year    category                                              prize  \
# 0    1970   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1970  Literature                 The Nobel Prize in Literature 1901
# 2    1970    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1970       Peace                         The Nobel Peace Prize 1901
# 4    1970       Peace                         The Nobel Peace Prize 1901
# ..    ...         ...                                                ...
# 473  1970   Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 475  1970  Literature                 The Nobel Prize in Literature 1977
# 482  1970     Physics                    The Nobel Prize in Physics 1977
# 491  1970     Physics                    The Nobel Prize in Physics 1978
# 495  1970   Chemistry                  The Nobel Prize in Chemistry 1979
#
# ...

# %%
nobel_db
# Out:
#      year   category                                              prize  \
# 0    1901  Economics                  The Nobel Prize in Chemistry 1901
# 1    1901  Economics                 The Nobel Prize in Literature 1901
# 2    1901  Economics     The Nobel Prize in Physiology or Medicine 1901
# 3    1901  Economics                         The Nobel Peace Prize 1901
# 4    1901  Economics                         The Nobel Peace Prize 1901
# ..    ...        ...                                                ...
# 473  1977  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 475  1977  Economics                 The Nobel Prize in Literature 1977
# 482  1977  Economics                    The Nobel Prize in Physics 1977
# 491  1978  Economics                    The Nobel Prize in Physics 1978
# 495  1979  Economics                  The Nobel Prize in Chemistry 1979
#
#                                             motivation prize_share  \
# ...

# %%
# Görselleştirme
plt.figure(figsize=(12, 8))

# Cinsiyete göre histogram
plt.subplot(2, 2, 1)
nobel_db['sex'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Cinsiyet Dağılımı')
plt.xlabel('Cinsiyet')
plt.ylabel('Kişi Sayısı')

# Yaş dağılımı
plt.subplot(2, 2, 2)
nobel_db['age_at_award'].plot(kind='hist', bins=20, color='green')
plt.title('Nobel Ödülü Kazananların Yaş Dağılımı')
plt.xlabel('Yaş')
plt.ylabel('Kişi Sayısı')

# Kategori dağılımı
plt.subplot(2, 2, 3)
nobel_db['category'].value_counts().plot(kind='bar', color='orange')
plt.title('Ödül Kategorisi Dağılımı')
plt.xlabel('Kategori')
plt.ylabel('Ödül Sayısı')

# Yıl dağılımı
plt.subplot(2, 2, 4)
nobel_db['year'].value_counts().sort_index().plot(kind='line', marker='o', color='red')
plt.title('Ödül Yılına Göre Dağılım')
plt.xlabel('Yıl')
plt.ylabel('Ödül Sayısı')

plt.tight_layout()
plt.show()

# %%
# Ödül kategorilerini al
categories = nobel_db['category'].unique()

# Her kategori için ayrı grafik oluştur
for category in categories:
    category_data = nobel_db[nobel_db['category'] == category]
    
    plt.figure(figsize=(10, 6))
    
    # Cinsiyete göre histogram
    plt.subplot(2, 2, 1)
    category_data['sex'].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f"{category} Kategorisinde Cinsiyet Dağılımı")
    plt.xlabel('Cinsiyet')
    plt.ylabel('Kişi Sayısı')
    
    # Yaş dağılımı
    plt.subplot(2, 2, 2)
    category_data['age_at_award'].plot(kind='hist', bins=20, color='green')
    plt.title(f"{category} Kategorisindeki Nobel Ödülü Kazananların Yaş Dağılımı")
    plt.xlabel('Yaş')
    plt.ylabel('Kişi Sayısı')
    
    # Ödül Yılına Göre Dağılım
    plt.subplot(2, 2, 3)
    category_data['year'].value_counts().sort_index().plot(kind='line', marker='o', color='red')
    plt.title(f"{category} Kategorisindeki Nobel Ödülü Kazananların Yıl Dağılımı")
    plt.xlabel('Yıl')
    plt.ylabel('Ödül Sayısı')
    
    plt.tight_layout()
    plt.show()

# %%
#ekonomistler=nobel_db[(nobel_db.category=="Economics") & (nobel_db.organization_country=="United States of America")]
#ekonomistler
